# %% [markdown]
# <a href="https://colab.research.google.com/github/Mijail-1/Consurso-de-preguntas-y-respuestas-Mijail-Makaroff/blob/main/Juegopreguntasrespuestas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from random import choice

puntuacion = 0

#----------------INICIO-----------------#

empezamos = input("Concurso de preguntas y respuestas!! \n1:iniciar \n2:salir \n3:Eliminar registros \n4:ver registros \n ")

print("----------------------------------------")

if empezamos == "1":
  nombre= input("Nombre: ")


  print("----------------------------------------")
  print("Hola",nombre,"Bienvenido a la ronda uno")
  print("Su puntuacion es: ", puntuacion)
  print("\n")

elif empezamos == "3":

  archivo=open("Guardado.csv","w")
  
  archivo.truncate()
  archivo.close()

  print("Registros eliminados")

elif empezamos == "4":

  df=pd.read_csv('Guardado.csv')
  print("----------------------------------------")
  print(df)
  print("----------------------------------------")
  sys.exit("bye")
else:
  sys.exit("bye")
  

#############categoria_1################

preguntas1 = ["Pregunta11? \na. \nb. \nc. \nd. Respuesta: ",
              "Pregunta12? \na. \nb. \nc. \nd. Respuesta: ",
              "Pregunta13? \na. \nb. \nc. \nd. Respuesta: ",
              "Pregunta14? \na. \nb. \nc. \nd. Respuesta: ",
              "Pregunta15? \na. \nb. \nc. \nd. Respuesta: "]

Pregunta1aleatroio = choice(preguntas1)
inp = input(Pregunta1aleatroio)
if inp == "a":
    print("Correcto!")
    puntuacion += 1
    print("Puntuacion: ", puntuacion)

else: 
    print("incorrecto!")
    print("su puntuacion final es: ", puntuacion)

    archivo=open("Guardado.csv","a")

    archivo.write(nombre)
    archivo.write(",")
    archivo.write(str(puntuacion))
    archivo.write("\n")

    archivo.close()

    sys.exit("bye")

print("----------------------------------------")

#############categoria_2################

preguntas2 = ["Pregunta21? \na. \nb. \nc. \nd. Respuesta: ",
              "Pregunta22? \na. \nb. \nc. \nd. Respuesta: ",
              "Pregunta23? \na. \nb. \nc. \nd. Respuesta: ",
              "Pregunta24? \na. \nb. \nc. \nd. Respuesta: ",
              "Pregunta25? \na. \nb. \nc. \nd. Respuesta: "]

Pregunta2aleatroio = choice(preguntas2)
inp2 = input(Pregunta2aleatroio)
if inp2 == "a":
    print("Correcto!")
    puntuacion += 1
    print("Puntuacion: ", puntuacion)
else: 
    print("incorrecto!")
    print("su puntuacion final es: ", puntuacion)

    archivo=open("Guardado.csv","a")

    archivo.write(nombre)
    archivo.write(",")
    archivo.write(str(puntuacion))
    archivo.write("\n")

    archivo.close()

    sys.exit("bye")

print("----------------------------------------")

#############categoria_3################

preguntas3 =[ "Pregunta31? \na. \nb. \nc. \nd. Respuesta: ",
              "Pregunta32? \na. \nb. \nc. \nd. Respuesta: ",
              "Pregunta33? \na. \nb. \nc. \nd. Respuesta: ",
              "Pregunta34? \na. \nb. \nc. \nd. Respuesta: ",
              "Pregunta35? \na. \nb. \nc. \nd. Respuesta: "]

Pregunta3aleatroio = choice(preguntas3)
inp3 = input(Pregunta3aleatroio)
if inp3 == "a":
    print("Correcto!")
    puntuacion += 1
    print("Puntuacion: ", puntuacion)
else: 
    print("incorrecto!")
    print("su puntuacion final es: ", puntuacion)

    archivo=open("Guardado.csv","a")

    archivo.write(nombre)
    archivo.write(",")
    archivo.write(str(puntuacion))
    archivo.write("\n")

    archivo.close()

    sys.exit("bye")

print("----------------------------------------")

#############categoria_4################

preguntas4 = ["Pregunta41? \na. \nb. \nc. \nd. Respuesta: ",
              "Pregunta42? \na. \nb. \nc. \nd. Respuesta: ",
              "Pregunta43? \na. \nb. \nc. \nd. Respuesta: ",
              "Pregunta44? \na. \nb. \nc. \nd. Respuesta: ",
              "Pregunta45? \na. \nb. \nc. \nd. Respuesta: "]


Pregunta4aleatroio = choice(preguntas4)
inp4 = input(Pregunta4aleatroio)
if inp4 == "a":
    print("Correcto!")
    puntuacion += 1
    print("Puntuacion: ", puntuacion)
else: 
    print("incorrecto!")
    print("su puntuacion final es: ", puntuacion)

    archivo=open("Guardado.csv","a")

    archivo.write(nombre)
    archivo.write(",")
    archivo.write(str(puntuacion))
    archivo.write("\n")

    archivo.close()


    sys.exit("bye")

print("----------------------------------------")

#############categoria_5################

preguntas5 = ["Pregunta51? \na. \nb. \nc. \nd. Respuesta: ",
              "Pregunta52? \na. \nb. \nc. \nd. Respuesta: ",
              "Pregunta53? \na. \nb. \nc. \nd. Respuesta: ",
              "Pregunta54? \na. \nb. \nc. \nd. Respuesta: ",
              "Pregunta55? \na. \nb. \nc. \nd. Respuesta: "]


Pregunta5aleatroio = choice(preguntas5)
inp5 = input(Pregunta5aleatroio)
if inp5 == "a":
    print("Correcto!")
    print("FELICITACIONES GANO EL JUEGO !!")
    puntuacion += 1
    print("Maxima puntuacion: ", puntuacion)

    #-------------Guardado resultados---------------#

    archivo=open("Guardado.csv","a")
    
    archivo.write(nombre)
    archivo.write(",")
    archivo.write(str(puntuacion))
    archivo.write("\n")
    
    archivo.close()

else: 
    print("incorrecto!")
    print("su puntuacion final es: ", puntuacion)

    #-------------Guardado resultados---------------#

    archivo=open("Guardado.csv","a")

    archivo.write(nombre)
    archivo.write(",")
    archivo.write(str(puntuacion))
    archivo.write("\n")

    archivo.close()

    sys.exit("bye")

print("----------------------------------------")
# Out:
# Concurso de preguntas y respuestas!!
# 1:iniciar
# 2:salir
# 3:Eliminar registros
# 4:ver registros
#  4
# ----------------------------------------
# ----------------------------------------
# Empty DataFrame
# Columns: [mijaa, 2]
# Index: []
# ----------------------------------------
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-d95344bd2609> in <module>()
#      36   print(df)
#      37   print("----------------------------------------")
# ---> 38   sys.exit("bye")
#      39 else:
#      40   sys.exit("bye")
#
# NameError: name 'sys' is not defined
